# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import random

# %%
x = np.random.random(1000)*100
y = np.random.random(1000)*100

# %%
plt.scatter(x,y,c="#00f",s=120,marker="*",alpha=0.1)

# %%
years=[2006 + x for x in range(16)]
weight=[40,42,45,47,48,50,52,43,67,56,54,56,67,34,45,78]
print(len(weight))
# Out:
# 16

# %%
plt.plot(years,weight)

# %%
lan =["C++","Python","Java","Go","Rust"]
per = [67,33,56,45,88]
plt.bar(lan,per,color="r",align="edge",width=0.5,edgecolor="Green",lw=0.1)
# Out:
# <BarContainer object of 5 artists>

# %%
age = np.random.normal(20,1.5,1000)
plt.hist(age,bins=[10,age.min(),18,21,age.max()])
# Out:
# (array([  0.,  92., 671., 237.]),
#  array([10.        , 15.35451092, 18.        , 21.        , 24.67394027]),
#  <BarContainer object of 4 artists>)

# %%
langs=["python","Go","Rust","C++","Swift"]
vote=[57,20,10,13,5]
explodes=[0,0,0,0.4,0]
plt.pie(vote,labels=langs, explode=explodes,autopct="%.2f%%",pctdistance=0.5,startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f7a1e13010>,
# ...
#  [Text(-1.090044725305083, -0.14765668570900078, 'python'),
#   Text(0.8391126587461305, -0.7112594083258232, 'Go'),
#   Text(1.079263179415325, 0.2125817244222193, 'Rust'),
#   Text(0.9526734174023044, 1.1586256340056589, 'C++'),
#   Text(0.16394626668668177, 1.087713942927781, 'Swift')],
#  [Text(-0.495474875138674, -0.06711667532227308, '54.29%'),
#   Text(0.38141484488460475, -0.32329973105719234, '19.05%'),
#   Text(0.4905741724615113, 0.09662805655555422, '9.52%'),
#   Text(0.5716040504413826, 0.6951753804033953, '12.38%'),
#   Text(0.07452103031212808, 0.4944154286035367, '4.76%')])

# %%
f = np.linspace(0,10,25)
s = np.linspace(40,50,23)
t = np.linspace(200,188,98)
fo = np.linspace(78,100,125)

ticks = np.concatenate((f,s,t,fo))
plt.boxplot(ticks)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f7a221f610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f7a2213990>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f7a221ed10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f7a222d710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f7a221e510>],
#  'means': []}

# %%
years = [2014,2015,2016,2017,2018,2019,2020,2021,2022]
income = [55,60,65,67,69,70,70,75,80]

income_tick = list(range(50,81,2))
plt.title("Income of faizan(in USDT)",fontsize=14)#fontname?
plt.xlabel("years")
plt.ylabel("Yearly income in usdt")
plt.yticks(income_tick,[f"${x}k" for x in income_tick])

plt.plot(years,income)
# Out:
# findfont: Font family 'FreeSerif' not found.
# findfont: Font family 'FreeSerif' not found.
# findfont: Font family 'FreeSerif' not found.
# findfont: Font family 'FreeSerif' not found.
# findfont: Font family 'FreeSerif' not found.
# findfont: Font family 'FreeSerif' not found.

# %%
stock_a = [12,34,54,62,65]
stock_b = [33,37,34,78,45]
stock_c = [15,39,76,12,34]
stock_d = [56,23,58,22,88]

plt.plot(stock_a,label="PK")
plt.plot(stock_b,label="IN")
plt.plot(stock_c,label="USA")
plt.plot(stock_d,label="KSA")
plt.legend(loc="lower center")

# %%
ax = plt.axes(projection="3d")

x=np.arange(-5,5,0.1)
Y=np.arange(-5,5,0.1)

X,Y = np.meshgrid(x,y)

Z = np.sin(X) * np.cos(Y)

ax.plot_surface(X,Y,Z,cmap="Spectral")

# %%
head_tail = [0,0]

for _ in range(10000):
    head_tail[random.randint(0,1)] +=1
    plt.bar(["Head","Tail"],head_tail,color=["red","Blue"])
    plt.pause(0.1)
